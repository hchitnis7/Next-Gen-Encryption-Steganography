# %%
import IWT_CLOUD_ENC_DEC as encryp

# %%
plaintext = 'MY NAME IS HARSH'

# %%
encryp.master_encrypt(plaintext, cover_image_path = 'lena2.png', output_path = 'encoded_image.png', output_qr_code_path = '/teamspace/studios/this_studio/project_dir/testqr.png', display = True)
# Out:
# [i] Starting generation...
# [i] Round 0/10 of key generation started
# [i] Initialised function.
# Choosing mode: high
# [i] Generating keys
# [i] Created.
# [i] Getting factors:
# [i] Factors: {}
# [i] Checking if key is long enough.
# Security passed
# [+] Done.
# NTRU Keys generated in: 0.82102370262146
# Final Length: 1268
# QR Code saved as /teamspace/studios/this_studio/project_dir/testqr.png!

# %%
encryp.master_decrypt(input_data='/teamspace/studios/this_studio/project_dir/testqr.png', downloaded_file_path = 'downloaded_file.png')
# Out:
# QR Code detected. Extracted URL: https://storage.googleapis.com/dctimages/encoded_image.png2025-04-04_14-22-19
# File downloaded and saved to downloaded_file.png.
# 'MY NAME IS HARSH'

# %%
plaintext = 'TEST USING HORSE IMAGE'

# %%
encryp.master_encrypt(plaintext, cover_image_path = '/teamspace/studios/this_studio/Wavelet-Image-Steganography/horse.png', output_path = 'encoded_image_horse.png', output_qr_code_path = '/teamspace/studios/this_studio/project_dir/testqr_horse.png', display = True)
# Out:
# [i] Starting generation...
# [i] Round 0/10 of key generation started
# [i] Initialised function.
# Choosing mode: high
# [i] Generating keys
# [i] Created.
# [i] Getting factors:
# [i] Factors: {}
# [i] Checking if key is long enough.
# Security passed
# [+] Done.
# NTRU Keys generated in: 0.7461693286895752
# Final Length: 2350
# QR Code saved as /teamspace/studios/this_studio/project_dir/testqr_horse.png!

# %%
encryp.master_decrypt(input_data='/teamspace/studios/this_studio/project_dir/testqr_horse.png', downloaded_file_path = 'downloaded_file_horse.png')
# Out:
# QR Code detected. Extracted URL: https://storage.googleapis.com/dctimages/encoded_image_horse.png2025-04-04_14-27-24
# File downloaded and saved to downloaded_file_horse.png.
# 'TEST USING HORSE IMAGE'

# %%
plaintext = 'TEST USING JAPAN IMAGE'

# %%
encryp.master_encrypt(plaintext, cover_image_path = '/teamspace/studios/this_studio/Wavelet-Image-Steganography/japan.jpg', output_path = 'encoded_image_japan.png', output_qr_code_path = '/teamspace/studios/this_studio/project_dir/testqr_japan.png', display = True)
# Out:
# [i] Starting generation...
# [i] Round 0/10 of key generation started
# [i] Initialised function.
# Choosing mode: high
# [i] Generating keys
# [i] Created.
# [i] Getting factors:
# [i] Factors: {}
# [i] Checking if key is long enough.
# Security passed
# [+] Done.
# NTRU Keys generated in: 0.6845388412475586
# Final Length: 2400
# QR Code saved as /teamspace/studios/this_studio/project_dir/testqr_japan.png!

# %%
encryp.master_decrypt(input_data='/teamspace/studios/this_studio/project_dir/testqr_japan.png', downloaded_file_path = 'downloaded_file_japan.png')
# Out:
# QR Code detected. Extracted URL: https://storage.googleapis.com/dctimages/encoded_image_japan.png2025-04-04_14-27-30
# File downloaded and saved to downloaded_file_japan.png.
# 'TEST USING JAPAN IMAGE'

# %%
plaintext = 'TEST USING MONALISA IMAGE'

# %%
encryp.master_encrypt(plaintext, cover_image_path = '/teamspace/studios/this_studio/Wavelet-Image-Steganography/monalisa.jpeg', output_path = 'encoded_image_monalisa.png', output_qr_code_path = '/teamspace/studios/this_studio/project_dir/testqr_monalisa.png', display = True)
# Out:
# [i] Starting generation...
# [i] Round 0/10 of key generation started
# [i] Initialised function.
# Choosing mode: high
# [i] Generating keys
# [i] Created.
# [i] Getting factors:
# [i] Factors: {}
# [i] Checking if key is long enough.
# Security passed
# [+] Done.
# NTRU Keys generated in: 0.703047513961792
# Final Length: 2402
# QR Code saved as /teamspace/studios/this_studio/project_dir/testqr_monalisa.png!

# %%
encryp.master_decrypt(input_data='/teamspace/studios/this_studio/project_dir/testqr_monalisa.png', downloaded_file_path = 'downloaded_file_monalisa.png')
# Out:
# QR Code detected. Extracted URL: https://storage.googleapis.com/dctimages/encoded_image_monalisa.png2025-04-04_14-27-38
# File downloaded and saved to downloaded_file_monalisa.png.
# 'TEST USING MONALISA IMAGE'

# %%
import IWT_CLOUD_ENC_DEC_numba as encryp_numba

# %%
plaintext = 'MY NAME IS HARSH'

# %%
encoded_img, qr_code_img = encryp_numba.master_encrypt(
    plaintext,
    cover_image_path='/teamspace/studios/this_studio/project_dir/lena.png',
    output_path='/teamspace/studios/this_studio/encoded_lena.png',
    display=True,
    cloud_upload=False
)
# Out:
# Final Length: 8256

# %%
decoded_message = encryp_numba.master_decrypt(
    input_data='/teamspace/studios/this_studio/encoded_lena.png',
    qr=False
)

# %%
decoded_message
# Out:
# 'MY NAME IS HARSH'
